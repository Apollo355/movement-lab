# %% [markdown]
# <a href="https://colab.research.google.com/github/Apollo355/movement-lab/blob/main/movement_lab_lesson_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# elbow sweeping smoothly from 0° to 90° over 5 frames
elbow = np.linspace(0, 90, 5)
print(elbow)
# Out:
# [ 0.  22.5 45.  67.5 90. ]

# %%
import numpy as np

# elbow sweeping smoothly from 0° to 90° over 5 frames
elbow = np.linspace(0, 90, 5)
print(elbow)
print(np.diff(elbow))
# Out:
# [ 0.  22.5 45.  67.5 90. ]
# [22.5 22.5 22.5 22.5]
